# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from Presentation.imports import *
from Presentation.predict import *
from fastai.vision import *

# %%
PATH = Path('data')

TRAIN = PATH/'train'
TEST = PATH/'test'
LABELS = PATH/'train.csv'
TEST = PATH/'test'
TEST_CSV = PATH/'sample_submission.csv'
ROOT = Path('data/demonstration')
MODEL = Path('data/Sample_model.pkl')

# Suffixes for image files for each sample (4 channels)
suffixes = ['_red.png', '_green.png', '_blue.png', '_yellow.png']

IDS = [o.name for o in ROOT.ls()]

# %%
prompt = "Do you want to make predictions based on a folder or ID (1 or 2) ? "

# %%
img = get_user_intent()
while img:
    print('go on')
    show_sample(img)
    
    img = get_user_intent()
# Out:
# Do you want to make predictions based on a folder or ID (1 or 2) ? exit

# %% [markdown]
# ### Experiment - predict

# %%
img = get_user_intent()
# Out:
# Do you want to make predictions based on a folder or ID (1 or 2) ? fg
# Enter the ID of the samples : 1cf6c924-bb9f-11e8-b2b9-ac1f6b6435d0

# %%
show_sample(img)

# %%
learn = load
