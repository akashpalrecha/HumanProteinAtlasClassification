# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
import cv2
import ResnetMultichannel.multichannel_resnet
from ResnetMultichannel.multichannel_resnet import get_arch as Resnet
import pdb
import shutil
from tqdm import tqdm_notebook as tqdm

from skmultilearn.model_selection import iterative_train_test_split
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9b10d9764e2f> in <module>
#       2 from fastai.vision import *
#       3 import cv2
# ----> 4 import ResnetMultichannel.multichannel_resnet
#       5 from ResnetMultichannel.multichannel_resnet import get_arch as Resnet
#       6 import pdb
#
# ModuleNotFoundError: No module named 'ResnetMultichannel.multichannel_resnet'

# %%
PATH = Path('data')

TRAIN = PATH/'train'
TEST = PATH/'test'
LABELS = PATH/'train.csv'
TEST = PATH/'test'
TEST_CSV = PATH/'sample_submission.csv'

# %% [markdown]
# # Data preparation

# %%
test_df = pd.read_csv(TEST_CSV)

# Gets complete path/filename for each test sample
test_fnames = [TEST/o for o in test_df['Id']]

# Training data
labels = pd.read_csv(LABELS)
labels.head(), len(labels)
# Out:
# (                                     Id   Target
#  0  00070df0-bbc3-11e8-b2bc-ac1f6b6435d0     16 0
#  1  000a6c98-bb9b-11e8-b2b9-ac1f6b6435d0  7 1 2 0
#  2  000a9596-bbc4-11e8-b2bc-ac1f6b6435d0        5
#  3  000c99ba-bba4-11e8-b2b9-ac1f6b6435d0        1
#  4  001838f8-bbca-11e8-b2bc-ac1f6b6435d0       18, 31072)

# %%
# This splits the label strings in the CSV to lists of integers
Y = np.array([list(map(int, s.split(' '))) for s in labels.Target])

# Get an array of File IDs
X = np.array(list(labels.Id))[:, None]

# %% [markdown]
# Creating a one hot encoded vector for all labels

# %%
y = np.zeros((len(Y), 28), dtype=int)

for i, label in enumerate(Y):
    for cls in label:
        y[i, cls] = 1

# %% [markdown]
# <hr>
# Multilabel stratification - train test split that takes care of representing rare classes equally in both <br>
# the training and validation sets in a multi label setting

# %%
np.random.seed(42)
X_train, Y_train, X_valid, Y_valid = iterative_train_test_split(X, y, 0.15)

# %%
def get_label_list_for_data_frame(label):
    return [' '.join(str(i[0]) for i in np.argwhere(label[o])) # gets indices of labels with value=1
              for o in range(len(label))]  # for all elements in Y_train

# %% [markdown]
# Get labels in the form a list of strings from a one hot encoded vector

# %%
Y_train = get_label_list_for_data_frame(Y_train)
Y_valid = get_label_list_for_data_frame(Y_valid)

# %% [markdown]
# Now, we need to create a dataframe for the testing and validation sets <br>
# Adding a `Valid` column to the DataFrames to aid in easily splitting the data into training and validation sets

# %%
train_df = pd.DataFrame.from_dict(data={'Id':X_train.squeeze(), 'Target': Y_train})
train_df['Valid'] = 0

valid_df = pd.DataFrame.from_dict(data={'Id':X_valid.squeeze(), 'Target': Y_valid})
valid_df['Valid'] = 1

LABELS_DF = pd.concat([train_df, valid_df], axis=0, ignore_index=True)

# %%
len(train_df), len(valid_df)
# Out:
# (26418, 4654)

# %% [markdown]
# # Creating Data for demonstration purposes

# %%
to_download = valid_df.sample(frac = 100/4654).reset_index()

# %%
to_download.head()
# Out:
#    index                                    Id Target  Valid
# 0   1228  1478fbb0-bbc1-11e8-b2bb-ac1f6b6435d0   1 23      1
# 1   1846  1f1db84c-bbc8-11e8-b2bc-ac1f6b6435d0      7      1
# 2   2884  30245fda-bba3-11e8-b2b9-ac1f6b6435d0     22      1
# 3   1840  1ef542c8-bba9-11e8-b2ba-ac1f6b6435d0      0      1
# 4   3596  3c6966a4-bbb3-11e8-b2ba-ac1f6b6435d0   0 25      1

# %%
# Suffixes for image files for each sample (4 channels)
suffixes = ['_red.png', '_green.png', '_blue.png', '_yellow.png']

# %%
def get_file_names(ID):
    ID = str(ID)
    return [ID + o for o in suffixes]

# %%
get_file_names(to_download.Id[0])
# Out:
# ['1478fbb0-bbc1-11e8-b2bb-ac1f6b6435d0_red.png',
#  '1478fbb0-bbc1-11e8-b2bb-ac1f6b6435d0_green.png',
#  '1478fbb0-bbc1-11e8-b2bb-ac1f6b6435d0_blue.png',
#  '1478fbb0-bbc1-11e8-b2bb-ac1f6b6435d0_yellow.png']

# %%
DWNLD = Path('data/demonstration')

# %%
def get_folder_for_ID(ID, PATH=DWNLD):
    ID_PATH = PATH/ID
    ID_PATH.mkdir(exist_ok=True)
    return ID_PATH

# %%
def copy_files_from_ID(ID, ROOT=TRAIN):
    FILES = get_file_names(ID)
    FOLDER = get_folder_for_ID(ID)
    for f in FILES:
        shutil.copy(ROOT/f, FOLDER/f)

# %%
for ID in tqdm(to_download.Id):
    copy_files_from_ID(ID)
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))

# %% [markdown]
# # Making predictions

# %%
def open_im_by_id(ID, ROOT=DWNLD, sufx=suffixes):
    """
    ID : Base name for each sample
    ROOT : Folder containing all samples
    sufx : color suffixes for samples
    """
    
     
    imnames = [ROOT/ID/(ID + o) for o in sufx] # Generating file names for given image ID
    imgs = [cv2.imread(str(o), cv2.IMREAD_GRAYSCALE) for o in imnames]  # List of 4 channels of given file ID
    imgs = np.stack(imgs, 2)
    return Image(pil2tensor(imgs, np.float32).float())  # Creating a Fastai Image object from the image

# %%
def open_im_by_folder(FOLDER, sufx=suffixes):
    """
    FOLDER : Folder containing sample files
    sufx : color suffixes for samples
    """
    FOLDER = Path(FOLDER)
    imnames = sorted(FOLDER.ls())
    imnames = [fnames[2], fnames[1], fnames[0], fnames[3]] # Sorting according to RGBY from BGRY
    imgs = [cv2.imread(str(o), cv2.IMREAD_GRAYSCALE) for o in imnames]  # List of 4 channels of given file ID
    imgs = np.stack(imgs, 2)
    return Image(pil2tensor(imgs, np.float32).float())  # Creating a Fastai Image object from the image

# %%
x = Path('data')

# %%
def get_folder_by_ID(ROOT=DWNLD):
    is_repeating = False
    is_ID_valid = False
    while not is_ID_valid:
        prompt = "Enter the ID of the samples : " if not is_repeating \
                 else "Please enter a valid ID : "
        try:
            ID = Path(input(prompt))
            folder = ROOT/ID
            if not folder.is_dir():
                raise FileNotFoundError
            else:
                is_ID_valid = True
        except FileNotFoundError:
            is_repeating = True
            is_ID_valid = False

    return folder

def get_folder():
    is_repeating = False
    is_folder_valid = False
    while not is_folder_valid:
        prompt = "Enter the location of the folder containing the samples : " if not is_repeating \
                 else "Please enter a valid folder : "
        try:
            folder = Path(input(prompt))
            if not folder.is_dir():
                raise FileNotFoundError
            else:
                is_folder_valid = True
        except FileNotFoundError:
            is_repeating = True
            is_folder_valid = False

    return folder

# %%
for i in range(10):
    is_folder = input("Do you want a folder ? (y / n) ")
    if is_folder == 'exit':
        break
    is_folder = True if is_folder == 'y' else False
    if is_folder:
        folder = get_folder()
    else:
        folder = get_folder_by_ID()
        
    img = open_im_by_folder(folder)
    
#         img = open_im_by_folder()
# Out:
# Do you want a folder ? (y / n) exit

# %%
def open_im_id(ID, path=TRAIN, sufx=suffixes):
    """
    Takes as input the ID of a sample, the `path` to the file
    And `sufx`, a list of all the suffixes for the files of different channels for the training sample
    """
    if str(ID).endswith('.png'):
        ID = str(ID)[:-4]
    else:
        ID = str(ID)
     
    imnames = [ID + o for o in sufx] # Generating file names for given image ID
    imgs = [cv2.imread(o, cv2.IMREAD_GRAYSCALE) for o in imnames]  # List of 4 channels of given file ID
    imgs = np.stack(imgs, 2)
    return Image(pil2tensor(imgs, np.float32).float())  # Creating a Fastai Image object from the image

open_func = partial(open_im_id, path=TRAIN, sufx=suffixes)

# %%
classes = """
Nucleoplasm  
Nuclear membrane   
Nucleoli   
Nucleoli fibrillar center   
Nuclear speckles   
Nuclear bodies   
Endoplasmic reticulum   
Golgi apparatus   
Peroxisomes   
Endosomes   
Lysosomes   
Intermediate filaments   
Actin filaments   
Focal adhesion sites   
Microtubules   
Microtubule ends   
Cytokinetic bridge   
Mitotic spindle   
Microtubule organizing center   
Centrosome   
Lipid droplets   
Plasma membrane   
Cell junctions   
Mitochondria   
Aggresome   
Cytosol   
Cytoplasmic bodies   
Rods & rings
"""

classes = classes.split('\n')[1:-1]

# %%
class CustomImageList(ImageItemList):
    def open(self, fn):
        return open_func(fn)
    
    
    # Customizing the function that shows the images to work with 4 channels by creating a new 3 channel Image
    # object every time an Image has to be shown
    def show_xys(self, xs, ys, imgsize:int=4, figsize:Optional[Tuple[int,int]]=None, **kwargs):
        "Show the `xs` (inputs) and `ys` (targets) on a figure of `figsize`."
        rows = int(np.ceil(math.sqrt(len(xs))))
        axs = subplots(rows, rows, imgsize=imgsize, figsize=figsize)
        for x,y,ax in zip(xs, ys, axs.flatten()):
            Image(x.data[[0,1,2],:,:]).show(ax=ax, y=y,
                                            title=' '.join([classes[o] for o in list(np.argwhere(y.data.numpy()).reshape(-1))]),
                                            **kwargs)
        for ax in axs.flatten()[len(xs):]: ax.axis('off')
        plt.tight_layout()

# %%
def remove_random_channels(tensor):
        """
        Assumes tensor.shape = [batch_size, channels, height_or_width, height_or_width]
        For each training sample in a batch:
        1. Selects a random number `N` in range (0, number_of_channels)
        2. Sets all values in channel N to zero
        """
        if isinstance(tensor, Image):
            tensor = tensor.data
        num_channels = tensor.shape[0]
        random_channel = 1
        #randomly select a different channel to be ignored for each sample in a batch except the protein channel
        while random_channel == 1:
            random_channel = np.random.randint(0, num_channels)

        #replce selected channels of samples with zeros

        tensor[random_channel] = torch.zeros_like(tensor[random_channel])
        return tensor

def get_custom_transforms():
    """
    Adds a transform to ignore channels in the list of transforms for training and validation data
    """
    tfms = get_transforms(do_flip=True, flip_vert=True, max_rotate=30., max_zoom=1,
                          max_lighting=0.05, max_warp=0.3)
#     add_to_tfms = TfmPixel(remove_random_channels)
#     add_to_tfms = RandTransform(add_to_tfms, kwargs={}, p=1.0)
#     tfms[0].append(add_to_tfms)
#     tfms[1].append(add_to_tfms)
#     tfms[0].append(to_half)
#     tfms[1].append(to_half)

    return tfms[0], tfms[1]


# Per channel mean and standard deviation
protein_stats = ([0.08069, 0.05258, 0.05487, 0.08282], [0.13704, 0.10145, 0.15313, 0.13814])

# %%
# np.random.seed(1)
data = (CustomImageList.from_df(LABELS_DF, PATH, folder='train', suffix='.png')
          .split_from_df()
          .label_from_df(sep=' ', classes=[str(i) for i in range(28)])
          .add_test(test_fnames, label='0')
          .transform(get_custom_transforms(), size=512)
          .databunch(bs=32)  # bs : batch size
          .normalize(protein_stats)
         )

# data.train_dl.add_tfm(to_half)
# data.valid_dl.add_tfm(to_half)

# %%
data.show_batch()

# %% [markdown]
# # Creating the model

# %% [markdown]
# ### Setting up losses and metrics

# %%
# Taken From:
# https://www.kaggle.com/iafoss/pretrained-resnet34-with-rgby-0-460-public-lb

class FocalLoss(nn.Module):
    def __init__(self, gamma=2):
        super().__init__()
        self.gamma = gamma
        
    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))

        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()

        invprobs = F.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        
        return loss.sum(dim=1).mean()

# %%
# Competition Metric
f1_score = partial(fbeta, thresh=0.3, beta=1)
# Accuracy over multiple classes. Each score above `thresh` will be treated as `Correct`
acc = partial(accuracy_thresh, thresh=0.3)

metrics = [acc, f1_score]
loss_function = FocalLoss()

# %% [markdown]
# ### Creating model object

# %% [markdown]
# _Model saving scheme:_ <br>
# `SpecialAPPROACH(es)_Architecture_ImageSize_FROZEN?_Epochs`

# %%
def save_model(model, approaches, arch, im_size, frozen, epochs):
    """
    Appropriately names and saves the model according to the paramaters
    """
    if isinstance(approaches, list):
        approaches = '-'.join(approaches)
    arch = str(arch)
    im_size = str(im_size)
    if isinstance(frozen, int):
        frozen = 'FreezeTo' + str(frozen)
    else:
        frozen = str(frozen)
    epochs = str(epochs)
    save_str = '_'.join([approaches, arch, im_size, frozen, epochs])
    model.save(save_str)
    print('Model Saved As :', save_str)
    
def load_model(model, approaches, arch, im_size, frozen, epochs):
    """
    Appropriately loads the model according to the given parameters
    """
    if isinstance(approaches, list):
        approaches = '-'.join(approaches)
    arch = str(arch)
    im_size = str(im_size)
    if isinstance(frozen, int):
        frozen = 'FreezeTo' + str(frozen)
    else:
        frozen = str(frozen)
    epochs = str(epochs)
    save_str = '_'.join([approaches, arch, im_size, frozen, epochs])
    model.load(save_str)
    print('Model Loaded from :', save_str)

# %%
MODEL_PATH = 'Models_Stratified_4_channel'

# Tells fastai where to form the layer groups
def _resnet_split(m:nn.Module): return (m[0][6],m[1])

# %%
resnet50 = Resnet(50, 4)

# %%
model = create_cnn(data, 
                   resnet50,
                   cut=-2,
                   split_on=_resnet_split, 
                   lin_ftrs=[512, 128, 28],
                   ps=0.4,
                   loss_func=loss_function,
                   path=PATH,
                   metrics=metrics,
                   model_dir=MODEL_PATH,
                   callback_fns = [ShowGraph]
                  )

# %%
print(model.summary())
# Out:
# ======================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ======================================================================
# Conv2d               [32, 64, 256, 256]   12544      False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 256, 256]   128        True
# ______________________________________________________________________
# ReLU                 [32, 64, 256, 256]   0          False
# ______________________________________________________________________
# MaxPool2d            [32, 64, 128, 128]   0          False
# ______________________________________________________________________
# Conv2d               [32, 64, 128, 128]   36864      False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 128, 128]   128        True
# ______________________________________________________________________
# ReLU                 [32, 64, 128, 128]   0          False
# ______________________________________________________________________
# Conv2d               [32, 64, 128, 128]   36864      False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 128, 128]   128        True
# ______________________________________________________________________
# Conv2d               [32, 64, 128, 128]   36864      False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 128, 128]   128        True
# ______________________________________________________________________
# ReLU                 [32, 64, 128, 128]   0          False
# ______________________________________________________________________
# Conv2d               [32, 64, 128, 128]   36864      False
# ______________________________________________________________________
# BatchNorm2d          [32, 64, 128, 128]   128        True
# ______________________________________________________________________
# Conv2d               [32, 128, 64, 64]    73728      False
# ______________________________________________________________________
# BatchNorm2d          [32, 128, 64, 64]    256        True
# ______________________________________________________________________
# ReLU                 [32, 128, 64, 64]    0          False
# ______________________________________________________________________
# Conv2d               [32, 128, 64, 64]    147456     False
# ______________________________________________________________________
# BatchNorm2d          [32, 128, 64, 64]    256        True
# ______________________________________________________________________
# Conv2d               [32, 128, 64, 64]    8192       False
# ______________________________________________________________________
# BatchNorm2d          [32, 128, 64, 64]    256        True
# ______________________________________________________________________
# Conv2d               [32, 128, 64, 64]    147456     False
# ______________________________________________________________________
# BatchNorm2d          [32, 128, 64, 64]    256        True
# ______________________________________________________________________
# ReLU                 [32, 128, 64, 64]    0          False
# ______________________________________________________________________
# Conv2d               [32, 128, 64, 64]    147456     False
# ______________________________________________________________________
# BatchNorm2d          [32, 128, 64, 64]    256        True
# ______________________________________________________________________
# Conv2d               [32, 256, 32, 32]    294912     False
# ______________________________________________________________________
# BatchNorm2d          [32, 256, 32, 32]    512        True
# ______________________________________________________________________
# ReLU                 [32, 256, 32, 32]    0          False
# ______________________________________________________________________
# Conv2d               [32, 256, 32, 32]    589824     False
# ______________________________________________________________________
# BatchNorm2d          [32, 256, 32, 32]    512        True
# ______________________________________________________________________
# Conv2d               [32, 256, 32, 32]    32768      False
# ______________________________________________________________________
# BatchNorm2d          [32, 256, 32, 32]    512        True
# ______________________________________________________________________
# Conv2d               [32, 256, 32, 32]    589824     False
# ______________________________________________________________________
# BatchNorm2d          [32, 256, 32, 32]    512        True
# ______________________________________________________________________
# ReLU                 [32, 256, 32, 32]    0          False
# ______________________________________________________________________
# Conv2d               [32, 256, 32, 32]    589824     False
# ______________________________________________________________________
# BatchNorm2d          [32, 256, 32, 32]    512        True
# ______________________________________________________________________
# Conv2d               [32, 512, 16, 16]    1179648    False
# ______________________________________________________________________
# BatchNorm2d          [32, 512, 16, 16]    1024       True
# ______________________________________________________________________
# ReLU                 [32, 512, 16, 16]    0          False
# ______________________________________________________________________
# Conv2d               [32, 512, 16, 16]    2359296    False
# ______________________________________________________________________
# BatchNorm2d          [32, 512, 16, 16]    1024       True
# ______________________________________________________________________
# Conv2d               [32, 512, 16, 16]    131072     False
# ______________________________________________________________________
# BatchNorm2d          [32, 512, 16, 16]    1024       True
# ______________________________________________________________________
# Conv2d               [32, 512, 16, 16]    2359296    False
# ______________________________________________________________________
# BatchNorm2d          [32, 512, 16, 16]    1024       True
# ______________________________________________________________________
# ReLU                 [32, 512, 16, 16]    0          False
# ______________________________________________________________________
# Conv2d               [32, 512, 16, 16]    2359296    False
# ______________________________________________________________________
# BatchNorm2d          [32, 512, 16, 16]    1024       True
# ______________________________________________________________________
# AdaptiveAvgPool2d    [32, 512, 1, 1]      0          False
# ______________________________________________________________________
# AdaptiveMaxPool2d    [32, 512, 1, 1]      0          False
# ______________________________________________________________________
# Lambda               [32, 1024]           0          False
# ______________________________________________________________________
# BatchNorm1d          [32, 1024]           2048       True
# ______________________________________________________________________
# Dropout              [32, 1024]           0          False
# ______________________________________________________________________
# Linear               [32, 512]            524800     True
# ______________________________________________________________________
# ReLU                 [32, 28]             0          False
# ______________________________________________________________________
# BatchNorm1d          [32, 512]            1024       True
# ______________________________________________________________________
# Dropout              [32, 512]            0          False
# ______________________________________________________________________
# Linear               [32, 128]            65664      True
# ______________________________________________________________________
# BatchNorm1d          [32, 128]            256        True
# ______________________________________________________________________
# Dropout              [32, 128]            0          False
# ______________________________________________________________________
# Linear               [32, 28]             3612       True
# ______________________________________________________________________
# BatchNorm1d          [32, 28]             56         True
# ______________________________________________________________________
# Dropout              [32, 28]             0          False
# ______________________________________________________________________
# Linear               [32, 28]             812        True
# ______________________________________________________________________
#
# Total params: 11777920
# Total trainable params: 607872
# Total non-trainable params: 11170048

# %% [markdown]
# # Begin Training

# %%
model.lr_find()
model.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
model.fit_one_cycle(2, 1e-2)
# Out:
# Total time: 11:43 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.315610</th>
#     <th>1.319489</th>
#     <th>0.843407</th>
#     <th>0.310040</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.237362</th>
#     <th>1.245677</th>
#     <th>0.856652</th>
#     <th>0.348246</th>
#   </tr>
# </table>

# %%
save_model(model, ['4_channel', 'stratified', 'focalLoss'], 'resnet50', 512, 'Frozen', 2)
# Out:
# Model Saved As : 4_channel-stratified-focalLoss_resnet50_512_Frozen_2

# %%
load_model(model, ['4_channel', 'stratified', 'focalLoss'], 'resnet50', 512, 'Frozen', 2)
# Out:
# Model Loaded from : 4_channel-stratified-focalLoss_resnet50_512_Frozen_2

# %%
model.freeze_to(-3)

# %%
lr = 5e-3
lrs = slice(lr/10, lr)

# %%
model.callback_fns.append(partial(GradientClipping, clip=1.0))

# %%
model.fit_one_cycle(3, lrs)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2' class='' max='3', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [2/3 10:51<05:25]
#     </div>
#
# <table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.281993</th>
#     <th>1.328841</th>
#     <th>0.875085</th>
#     <th>0.327151</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.207961</th>
#     <th>1.247791</th>
#     <th>0.857243</th>
#     <th>0.338277</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='462' class='' max='825', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       56.00% [462/825 02:42<02:07 1.1978]
#     </div>

# %%
save_model(model, ['4_channel', 'stratified', 'focalLoss'], 'resnet50', 512, -3, 2)

# %%
load_model(model, ['4_channel', 'stratified', 'focalLoss'], 'resnet50', 512, -3, 2)

# %%
model.freeze_to(-7)

# %%
model.lr_find()
model.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
f1_score_0 = partial(fbeta, thresh=0.0, beta=1)
model.metrics.append(f1_score_0)
acc_0 = partial(accuracy_thresh, thresh=0.3)
model.metrics.append(acc_0)

# %%
lr = 3e-4
lrs = slice(lr/20, lr)
wd = 1e-3
# wds = slice(wd/20, wd)

# %%
model.fit_one_cycle(4, lrs, wd=wd)
# Out:
# Total time: 20:00 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.197382</th>
#     <th>1.171124</th>
#     <th>0.868530</th>
#     <th>0.373658</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.199967</th>
#     <th>1.174368</th>
#     <th>0.863320</th>
#     <th>0.368260</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.201236</th>
#     <th>1.167585</th>
#     <th>0.864788</th>
#     <th>0.372048</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.187225</th>
#     <th>1.179557</th>
#     <th>0.861507</th>
#     <th>0.367061</th>
#   </tr>
# </table>

# %%
save_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, -7, 9)
# Out:
# Model Saved As : stratified-focalLoss_resnet50_512_FreezeTo-7_9

# %%
load_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, -7, 9)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-26-3aac7c0b9219> in <module>
# ----> 1 load_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, -7, 9)
#
# <ipython-input-20-03ec47a58b15> in load_model(model, approaches, arch, im_size, frozen, epochs)
#      30     epochs = str(epochs)
#      31     save_str = '_'.join([approaches, arch, im_size, frozen, epochs])
# ---> 32     model.load(save_str)
#      33     print('Model Loaded from :', save_str)
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in load(self, name, device, strict, with_opt)
#     215         "Load model and optimizer state (if `with_opt`) `name` from `self.model_dir` using `device`."
#     216         if device is None: device = self.data.device
# --> 217         state = torch.load(self.path/self.model_dir/f'{name}.pth', map_location=device)
#     218         if set(state.keys()) == {'model', 'opt'}:
#     219             get_model(self.model).load_state_dict(state['model'], strict=strict)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     363             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     364         new_fd = True
# --> 365         f = open(f, 'rb')
#     366     try:
#     367         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Models_Stratified_4_channel/stratified-focalLoss_resnet50_512_FreezeTo-7_9.pth'

# %%
model.unfreeze()
model.callback_fns.append(partial(GradientClipping, clip=0.6))
# model.lr_find()
# model.recorder.plot()

# %%
lr = 1e-4
lrs = slice(lr/30, lr)
wd = 1e-3
# wds = slice(wd/20, wd)
model.fit_one_cycle(5, lrs, wd=wd)
# Out:
# Total time: 25:11 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.193727</th>
#     <th>1.172013</th>
#     <th>0.863774</th>
#     <th>0.371002</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.205501</th>
#     <th>1.165357</th>
#     <th>0.866578</th>
#     <th>0.374898</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>1.190567</th>
#     <th>1.170330</th>
#     <th>0.863505</th>
#     <th>0.370655</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>1.211718</th>
#     <th>1.171455</th>
#     <th>0.861738</th>
#     <th>0.367477</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>1.185368</th>
#     <th>1.166423</th>
#     <th>0.863236</th>
#     <th>0.371123</th>
#   </tr>
# </table>

# %%
save_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, 'unfrozen', 15)
# Out:
# Model Saved As : stratified-focalLoss_resnet50_512_unfrozen_15

# %%
load_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, 'unfrozen', 15)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-25-5d82f61ccd14> in <module>
# ----> 1 load_model(model, ['stratified', 'focalLoss'], 'resnet50', 512, 'unfrozen', 15)
#
# <ipython-input-20-03ec47a58b15> in load_model(model, approaches, arch, im_size, frozen, epochs)
#      30     epochs = str(epochs)
#      31     save_str = '_'.join([approaches, arch, im_size, frozen, epochs])
# ---> 32     model.load(save_str)
#      33     print('Model Loaded from :', save_str)
#
# ~/anaconda3/lib/python3.7/site-packages/fastai/basic_train.py in load(self, name, device, strict, with_opt)
#     215         "Load model and optimizer state (if `with_opt`) `name` from `self.model_dir` using `device`."
#     216         if device is None: device = self.data.device
# --> 217         state = torch.load(self.path/self.model_dir/f'{name}.pth', map_location=device)
#     218         if set(state.keys()) == {'model', 'opt'}:
#     219             get_model(self.model).load_state_dict(state['model'], strict=strict)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     363             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     364         new_fd = True
# --> 365         f = open(f, 'rb')
#     366     try:
#     367         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/Models_Stratified_4_channel/stratified-focalLoss_resnet50_512_unfrozen_15.pth'

# %%
lr = 1e-5
lrs = slice(lr/10, lr)
wd = 1e-3
# wds = slice(wd/20, wd)
model.fit_one_cycle(2, lrs, wd=wd)
# Out:
# Total time: 10:07 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>1.193127</th>
#     <th>1.177757</th>
#     <th>0.862852</th>
#     <th>0.369105</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>1.184299</th>
#     <th>1.178697</th>
#     <th>0.860793</th>
#     <th>0.365032</th>
#   </tr>
# </table>
